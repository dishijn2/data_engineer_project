# %%
# !pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 819.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 7.0 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/11.5 MB 3.7 MB/s eta 0:00:04
#    -- ------------------------------------- 0.7/11.5 MB 4.9 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/11.5 MB 6.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.5 MB 6.5 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/11.5 MB 6.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.5/11.5 MB 7.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.5 MB 8.2 MB/s eta 0:00:02
# ...

# %%
import psycopg2
import pandas as pd
